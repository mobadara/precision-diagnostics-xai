# %% [markdown]
# <a href="https://colab.research.google.com/github/mobadara/precision-diagnostics-xai/blob/main/notebooks/model_training_and_finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
